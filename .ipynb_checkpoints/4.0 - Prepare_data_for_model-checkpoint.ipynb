# %%
from data_reader import InHospitalMortalityReader
import pandas as pd
import numpy as np
import matplotlib as plt
import shutil
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

#from Preprocessing import *
from CustomImputer import Impute
# Build readers

#val_reader = InHospitalMortalityReader(dataset_dir='/datasets/train/', listfile='/datasets/train/val_listfile.csv', period_length=48.0)

# %% [markdown]
# val_patients  = set()
# with open(f"./resources/valset.csv", "r") as valset_file:
#     for line in valset_file:
#         x, y = line.split(',')
#         if int(y) == 1:
#             val_patients.add(x)
#
# with open(f"./datasets/ihm/train/listfile.csv") as listfile:
#     lines = listfile.readlines()
#     header = lines[0]
#     lines = lines[1:]
#
# train_lines = [x for x in lines if x[:x.find("_")] not in val_patients]
# val_lines = [x for x in lines if x[:x.find("_")] in val_patients]
# assert len(train_lines) + len(val_lines) == len(lines)
#
# with open(f"./datasets/ihm/train_listfile.csv", "w") as train_listfile:
#     train_listfile.write(header)
#     for line in train_lines:
#         train_listfile.write(line)
#
# with open(f"./datasets/ihm/val_listfile.csv", "w") as val_listfile:
#     val_listfile.write(header)
#     for line in val_lines:
#         val_listfile.write(line)
#
#
# shutil.copy(f"./datasets/ihm/test/listfile.csv",
#             f"./datasets/ihm/test_listfile.csv")

# %% [markdown]
# # Load data
#
# Gather test and training data.
# uses one hot encoding for categorical variables.
#
# small_part selects only 1000 patients

# %%
train_reader = InHospitalMortalityReader(dataset_dir='./datasets/ihm/train/', listfile='./datasets/ihm/train_listfile.csv', period_length=48.0)
test_reader = InHospitalMortalityReader(dataset_dir='./datasets/ihm/test/', listfile='./datasets/ihm/test_listfile.csv', period_length=48.0)
val_reader = InHospitalMortalityReader(dataset_dir='./datasets/ihm/train/', listfile='./datasets/ihm/val_listfile.csv', period_length=48.0)
discretizer = Discretizer(timestep=float(1.0),
                          store_masks=False,
                          imput_strategy='previous',
                          start_time='zero')


#cont_channels = [i for (i, x) in enumerate(train_raw[0][0].columns) if x.find("->") == -1]

#normalizer = Normalizer(fields=cont_channels)  # choose here onlycont vs all
#normalizer.load_params('ihm_ts%s.input_str:%s.start_time:zero.normalizer' % (1.0, 'previous'))

train_raw = train_reader._load_data( discretizer, small_part=False)
test_raw = test_reader._load_data(discretizer, small_part=False)
val_raw = val_reader._load_data(discretizer, small_part=False)
# Out:
# processed 1 / 14681
# processed 101 / 14681
# processed 201 / 14681
# processed 301 / 14681
# processed 401 / 14681
# processed 501 / 14681
# processed 601 / 14681
# processed 701 / 14681
# processed 801 / 14681
# processed 901 / 14681
# processed 1001 / 14681
# processed 1101 / 14681
# processed 1201 / 14681
# processed 1301 / 14681
# processed 1401 / 14681
# processed 1501 / 14681
# processed 1601 / 14681
# processed 1701 / 14681
# processed 1801 / 14681
# processed 1901 / 14681
# processed 2001 / 14681
# processed 2101 / 14681
# processed 2201 / 14681
# processed 2301 / 14681
# processed 2401 / 14681
# processed 2501 / 14681
# processed 2601 / 14681
# processed 2701 / 14681
# processed 2801 / 14681
# processed 2901 / 14681
# processed 3001 / 14681
# processed 3101 / 14681
# processed 3201 / 14681
# processed 3301 / 14681
# processed 3401 / 14681
# processed 3501 / 14681
# processed 3601 / 14681
# processed 3701 / 14681
# processed 3801 / 14681
# processed 3901 / 14681
# processed 4001 / 14681
# processed 4101 / 14681
# processed 4201 / 14681
# processed 4301 / 14681
# processed 4401 / 14681
# processed 4501 / 14681
# processed 4601 / 14681
# processed 4701 / 14681
# processed 4801 / 14681
# processed 4901 / 14681
# processed 5001 / 14681
# processed 5101 / 14681
# processed 5201 / 14681
# processed 5301 / 14681
# processed 5401 / 14681
# processed 5501 / 14681
# processed 5601 / 14681
# processed 5701 / 14681
# processed 5801 / 14681
# processed 5901 / 14681
# processed 6001 / 14681
# processed 6101 / 14681
# processed 6201 / 14681
# processed 6301 / 14681
# processed 6401 / 14681
# processed 6501 / 14681
# processed 6601 / 14681
# processed 6701 / 14681
# processed 6801 / 14681
# processed 6901 / 14681
# processed 7001 / 14681
# processed 7101 / 14681
# processed 7201 / 14681
# processed 7301 / 14681
# processed 7401 / 14681
# processed 7501 / 14681
# processed 7601 / 14681
# processed 7701 / 14681
# processed 7801 / 14681
# processed 7901 / 14681
# processed 8001 / 14681
# processed 8101 / 14681
# processed 8201 / 14681
# processed 8301 / 14681
# processed 8401 / 14681
# processed 8501 / 14681
# processed 8601 / 14681
# processed 8701 / 14681
# processed 8801 / 14681
# processed 8901 / 14681
# processed 9001 / 14681
# processed 9101 / 14681
# processed 9201 / 14681
# processed 9301 / 14681
# processed 9401 / 14681
# processed 9501 / 14681
# processed 9601 / 14681
# processed 9701 / 14681
# processed 9801 / 14681
# processed 9901 / 14681
# processed 10001 / 14681
# processed 10101 / 14681
# processed 10201 / 14681
# processed 10301 / 14681
# processed 10401 / 14681
# processed 10501 / 14681
# processed 10601 / 14681
# processed 10701 / 14681
# processed 10801 / 14681
# processed 10901 / 14681
# processed 11001 / 14681
# processed 11101 / 14681
# processed 11201 / 14681
# processed 11301 / 14681
# processed 11401 / 14681
# processed 11501 / 14681
# processed 11601 / 14681
# processed 11701 / 14681
# processed 11801 / 14681
# processed 11901 / 14681
# processed 12001 / 14681
# processed 12101 / 14681
# processed 12201 / 14681
# processed 12301 / 14681
# processed 12401 / 14681
# processed 12501 / 14681
# processed 12601 / 14681
# processed 12701 / 14681
# processed 12801 / 14681
# processed 12901 / 14681
# processed 13001 / 14681
# processed 13101 / 14681
# processed 13201 / 14681
# processed 13301 / 14681
# processed 13401 / 14681
# processed 13501 / 14681
# processed 13601 / 14681
# processed 13701 / 14681
# processed 13801 / 14681
# processed 13901 / 14681
# processed 14001 / 14681
# processed 14101 / 14681
# processed 14201 / 14681
# processed 14301 / 14681
# processed 14401 / 14681
# processed 14501 / 14681
# processed 14601 / 14681
# processed 1 / 3236
# processed 101 / 3236
# processed 201 / 3236
# processed 301 / 3236
# processed 401 / 3236
# processed 501 / 3236
# processed 601 / 3236
# processed 701 / 3236
# processed 801 / 3236
# processed 901 / 3236
# processed 1001 / 3236
# processed 1101 / 3236
# processed 1201 / 3236
# processed 1301 / 3236
# processed 1401 / 3236
# processed 1501 / 3236
# processed 1601 / 3236
# processed 1701 / 3236
# processed 1801 / 3236
# processed 1901 / 3236
# processed 2001 / 3236
# processed 2101 / 3236
# processed 2201 / 3236
# processed 2301 / 3236
# processed 2401 / 3236
# processed 2501 / 3236
# processed 2601 / 3236
# processed 2701 / 3236
# processed 2801 / 3236
# processed 2901 / 3236
# processed 3001 / 3236
# processed 3101 / 3236
# processed 3201 / 3236
# processed 1 / 3222
# processed 101 / 3222
# processed 201 / 3222
# processed 301 / 3222
# processed 401 / 3222
# processed 501 / 3222
# processed 601 / 3222
# processed 701 / 3222
# processed 801 / 3222
# processed 901 / 3222
# processed 1001 / 3222
# processed 1101 / 3222
# processed 1201 / 3222
# processed 1301 / 3222
# processed 1401 / 3222
# processed 1501 / 3222
# processed 1601 / 3222
# processed 1701 / 3222
# processed 1801 / 3222
# processed 1901 / 3222
# processed 2001 / 3222
# processed 2101 / 3222
# processed 2201 / 3222
# processed 2301 / 3222
# processed 2401 / 3222
# processed 2501 / 3222
# processed 2601 / 3222
# processed 2701 / 3222
# processed 2801 / 3222
# processed 2901 / 3222
# processed 3001 / 3222
# processed 3101 / 3222
# processed 3201 / 3222

# %%
train_raw[0].head()
# Out:
#       Hours Capillary refill rate Diastolic blood pressure  \
# 0  1.746111                   0.0                     59.0
# 1  2.196111                   0.0                     59.0
# 2  2.212778                   0.0                     59.0
# 3  2.279444                   0.0                       81
# 4  2.496111                   0.0                       81
#
#   Fraction inspired oxygen Glascow coma scale eye opening  \
# 0                     0.21                  Spontaneously
# 1                     0.21                  Spontaneously
# 2                     0.21                  Spontaneously
# 3                     0.21                  Spontaneously
# 4                     0.21                  Spontaneously
#
#   Glascow coma scale motor response Glascow coma scale total  \
# 0                    Obeys Commands                       15
# 1                    Obeys Commands                       15
# 2                    Obeys Commands                       15
# 3                    Obeys Commands                       15
# 4                    Obeys Commands                       15
#
#   Glascow coma scale verbal response Glucose Heart Rate Height  \
# 0                           Oriented   128.0         86  170.0
# 1                           Oriented   128.0         76  170.0
# 2                           Oriented   128.0         76  170.0
# 3                           Oriented   128.0         76  170.0
# 4                           Oriented   128.0         72  170.0
#
#   Mean blood pressure  Oxygen saturation Respiratory rate  \
# 0                77.0               94.0               19
# 1                77.0               94.0               19
# 2                77.0               94.0               16
# 3                 104               95.0               16
# 4                 104               94.0               12
#
#   Systolic blood pressure Temperature Weight   pH  Mortality  \
# 0                   118.0        36.6   81.0  7.5          0
# 1                   118.0        36.6   81.0  7.5          0
# 2                   118.0        36.6   81.0  7.5          0
# 3                     174        36.6   81.0  7.5          0
# 4                     174        37.5   81.0  7.5          0
#
#                          Episode
# 0  99260_episode2_timeseries.csv
# 1  99260_episode2_timeseries.csv
# 2  99260_episode2_timeseries.csv
# 3  99260_episode2_timeseries.csv
# 4  99260_episode2_timeseries.csv

# %% [markdown]
# # Concat data

# %%
def concat_data(data):
    complete_data =  pd.DataFrame(columns=data[0].columns)
    for patient in data:
        complete_data = pd.concat([complete_data,patient])
    return complete_data

train = concat_data(train_raw)
test = concat_data(test_raw)
val = concat_data(val_raw)

# %%
train.head()
# Out:
#       Hours Capillary refill rate Diastolic blood pressure  \
# 0  1.746111                   0.0                     59.0
# 1  2.196111                   0.0                     59.0
# 2  2.212778                   0.0                     59.0
# 3  2.279444                   0.0                       81
# 4  2.496111                   0.0                       81
#
#   Fraction inspired oxygen Glascow coma scale eye opening  \
# 0                     0.21                  Spontaneously
# 1                     0.21                  Spontaneously
# 2                     0.21                  Spontaneously
# 3                     0.21                  Spontaneously
# 4                     0.21                  Spontaneously
#
#   Glascow coma scale motor response Glascow coma scale total  \
# 0                    Obeys Commands                       15
# 1                    Obeys Commands                       15
# 2                    Obeys Commands                       15
# 3                    Obeys Commands                       15
# 4                    Obeys Commands                       15
#
#   Glascow coma scale verbal response Glucose Heart Rate Height  \
# 0                           Oriented   128.0         86  170.0
# 1                           Oriented   128.0         76  170.0
# 2                           Oriented   128.0         76  170.0
# 3                           Oriented   128.0         76  170.0
# 4                           Oriented   128.0         72  170.0
#
#   Mean blood pressure Oxygen saturation Respiratory rate  \
# 0                77.0                94               19
# 1                77.0                94               19
# 2                77.0                94               16
# 3                 104                95               16
# 4                 104                94               12
#
#   Systolic blood pressure Temperature Weight   pH Mortality  \
# 0                   118.0        36.6   81.0  7.5         0
# 1                   118.0        36.6   81.0  7.5         0
# 2                   118.0        36.6   81.0  7.5         0
# 3                     174        36.6   81.0  7.5         0
# 4                     174        37.5   81.0  7.5         0
#
#                          Episode
# 0  99260_episode2_timeseries.csv
# 1  99260_episode2_timeseries.csv
# 2  99260_episode2_timeseries.csv
# 3  99260_episode2_timeseries.csv
# 4  99260_episode2_timeseries.csv

# %%
train.to_csv('./datasets/ihm/train.csv')
test.to_csv('./datasets/ihm/test.csv')
val.to_csv('./datasets/ihm/val.csv')

# %% [markdown]
# # Check for duplicate categorical values

# %%
print(test['Glascow coma scale verbal response'].unique())

print(test['Glascow coma scale eye opening'].unique())

print(test['Glascow coma scale motor response'].unique())
# Out:
# ['Oriented' 'Confused' 'Inappropriate Words' 'Incomprehensible sounds'
#  'No Response']
# ['Spontaneously' 'To Speech' 'To Pain' 'No response' 'None']
# ['Obeys Commands' 'Localizes Pain' 'Flex-withdraws' 'No response'
#  'Abnormal Flexion' 'Abnormal extension']

# %%
def remove_duplicate_values(data):
    data['Glascow coma scale verbal response'].replace(['1 No Response', 'No Response-ETT','1.0 ET/Trach'], 'No Response', inplace=True)
    data['Glascow coma scale verbal response'].replace('2 Incomp sounds', 'Incomprehensible sounds', inplace=True)
    data['Glascow coma scale verbal response'].replace('3 Inapprop words', 'Inappropriate Words', inplace=True)
    data['Glascow coma scale verbal response'].replace('4 Confused', 'Confused', inplace=True)
    data['Glascow coma scale verbal response'].replace('5 Oriented', 'Oriented', inplace=True)
    
    data['Glascow coma scale eye opening'].replace('1 No Response','No response', inplace=True )
    data['Glascow coma scale eye opening'].replace('2 To pain','To Pain' , inplace=True)
    data['Glascow coma scale eye opening'].replace('3 To speech','To Speech' , inplace=True)
    data['Glascow coma scale eye opening'].replace('4 Spontaneously','Spontaneously', inplace=True )
    
    data['Glascow coma scale motor response'].replace('1 No Response','No response', inplace=True )
    data['Glascow coma scale motor response'].replace('2 Abnorm extensn','Abnormal extension', inplace=True )
    data['Glascow coma scale motor response'].replace('3 Abnorm flexion','Abnormal Flexion', inplace=True )
    data['Glascow coma scale motor response'].replace('4 Flex-withdraws','Flex-withdraws', inplace=True )
    data['Glascow coma scale motor response'].replace('5 Localizes Pain','Localizes Pain', inplace=True )
    data['Glascow coma scale motor response'].replace('6 Obeys Commands','Obeys Commands', inplace=True )
    return data
 
train = remove_duplicate_values(train) 
test = remove_duplicate_values(test)
val = remove_duplicate_values(val)

# %%
print(test['Glascow coma scale verbal response'].unique())

print(test['Glascow coma scale eye opening'].unique())

print(test['Glascow coma scale motor response'].unique())
# Out:
# ['Oriented' 'Confused' 'Inappropriate Words' 'Incomprehensible sounds'
#  'No Response']
# ['Spontaneously' 'To Speech' 'To Pain' 'No response' 'None']
# ['Obeys Commands' 'Localizes Pain' 'Flex-withdraws' 'No response'
#  'Abnormal Flexion' 'Abnormal extension']

# %%
train.to_csv('./datasets/ihm/train.csv')
test.to_csv('./datasets/ihm/test.csv')
val.to_csv('./datasets/ihm/val.csv')
