# %% [markdown]
# # Sort the data into a train and test set
#
# This splits the data into a trainset and a testset.
# I have used the same testset from the github project to be able to give a more precise comparrison between my fast ai approach and their approach
#
#  The reason for making a general dataset is to be able to do training on other areas of the data if time and resources allow it

# %%
import os
import shutil

DATA_PATH = f'./data/'

testset = set()
with open("resources/testset.csv", "r") as test_set_file:
    for line in test_set_file:
        x, y = line.split(',')
        if int(y) == 1:
            testset.add(x)

def move_to_partition(patients, partition):
    if not os.path.exists(os.path.join(DATA_PATH, partition)):
        os.mkdir(os.path.join(DATA_PATH, partition))
    for patient in patients:
        src = os.path.join(DATA_PATH, patient)
        dest = os.path.join(DATA_PATH, partition, patient)
        shutil.move(src, dest)


folders = os.listdir(DATA_PATH)
folders = list((filter(str.isdigit, folders)))
train_patients = [x for x in folders if not x in testset]
test_patients = [x for x in folders if x in testset]

assert len(set(train_patients) & set(test_patients)) == 0

move_to_partition(train_patients, "train")
move_to_partition(test_patients, "test")

# %% [markdown]
# This takes the train and test set and creates datasets which are specific for predicting mortality test.

# %%
from __future__ import print_function

import pandas as pd
import random
random.seed(49297)

FINAL_DATA_PATH = f'./datasets/'

if not os.path.exists(FINAL_DATA_PATH):
    os.makedirs(FINAL_DATA_PATH)


def process_partition(partition, eps=1e-6, n_hours=48):
    output_dir = os.path.join(FINAL_DATA_PATH, partition)
    if (not os.path.exists(output_dir)):
        os.mkdir(output_dir)

    xy_pairs = []
    patients = list(filter(str.isdigit, os.listdir(os.path.join(DATA_PATH, partition))))
    for (patient_index, patient) in enumerate(patients):
        patient_folder = os.path.join(DATA_PATH, partition, patient)
        patient_ts_files = list(filter(lambda x: x.find("timeseries") != -1, os.listdir(patient_folder)))

        for ts_filename in patient_ts_files:
            with open(os.path.join(patient_folder, ts_filename)) as tsfile:
                lb_filename = ts_filename.replace("_timeseries", "")
                label_df = pd.read_csv(os.path.join(patient_folder, lb_filename))

                # empty label file
                if (label_df.shape[0] == 0):
                    continue

                mortality = int(label_df.iloc[0]["Mortality"])
                los = 24.0 * label_df.iloc[0]['Length of Stay'] # in hours
                if (pd.isnull(los)):
                    print("\n\t(length of stay is missing)", patient, ts_filename)
                    continue

                if (los < n_hours - eps):
                    continue

                ts_lines = tsfile.readlines()
                header = ts_lines[0]
                ts_lines = ts_lines[1:]
                event_times = [float(line.split(',')[0]) for line in ts_lines]

                ts_lines = [line for (line, t) in zip(ts_lines, event_times)
                                     if (t > -eps and t < n_hours + eps)]
                event_times = [t for t in event_times
                                     if (t > -eps and t < n_hours + eps)]

                # no measurements in ICU
                if (len(ts_lines) == 0):
                    print("\n\t(no events in ICU) ", patient, ts_filename)
                    continue

                output_ts_filename = patient + "_" + ts_filename
                with open(os.path.join(output_dir, output_ts_filename), "w") as outfile:
                    outfile.write(header)
                    for line in ts_lines:
                        outfile.write(line)

                xy_pairs.append((output_ts_filename, mortality))

        if ((patient_index + 1) % 100 == 0):
            print("\rprocessed {} / {} patients".format(patient_index + 1, len(patients)))

    print("\n", len(xy_pairs))
    if partition == "train":
        random.shuffle(xy_pairs)
    if partition == "test":
        xy_pairs = sorted(xy_pairs)

    with open(os.path.join(output_dir, "listfile.csv"), "w") as listfile:
        listfile.write('stay,y_true\n')
        for (x, y) in xy_pairs:
            listfile.write("%s,%d\n" % (x, y))


process_partition("test")
process_partition("train")
# Out:
# 	(no events in ICU)  52808 episode2_timeseries.csv
# processed 100 / 5070 patients
# processed 200 / 5070 patients
# processed 300 / 5070 patients
# processed 400 / 5070 patients
# processed 500 / 5070 patients
# processed 600 / 5070 patients
# processed 700 / 5070 patients
# processed 800 / 5070 patients
# processed 900 / 5070 patients
# processed 1000 / 5070 patients
# processed 1100 / 5070 patients
#
# 	(no events in ICU)  21341 episode1_timeseries.csv
# processed 1200 / 5070 patients
# processed 1300 / 5070 patients
# processed 1400 / 5070 patients
# processed 1500 / 5070 patients
# processed 1600 / 5070 patients
# processed 1700 / 5070 patients
# processed 1800 / 5070 patients
# processed 1900 / 5070 patients
# processed 2000 / 5070 patients
# processed 2100 / 5070 patients
# processed 2200 / 5070 patients
# processed 2300 / 5070 patients
# processed 2400 / 5070 patients
# processed 2500 / 5070 patients
# processed 2600 / 5070 patients
#
# 	(no events in ICU)  7512 episode1_timeseries.csv
# processed 2700 / 5070 patients
# processed 2800 / 5070 patients
# processed 2900 / 5070 patients
# processed 3000 / 5070 patients
# processed 3100 / 5070 patients
# processed 3200 / 5070 patients
# processed 3300 / 5070 patients
# processed 3400 / 5070 patients
# processed 3500 / 5070 patients
# processed 3600 / 5070 patients
# processed 3700 / 5070 patients
# processed 3800 / 5070 patients
# processed 3900 / 5070 patients
# processed 4000 / 5070 patients
# processed 4100 / 5070 patients
# processed 4200 / 5070 patients
# processed 4300 / 5070 patients
# processed 4400 / 5070 patients
# processed 4500 / 5070 patients
# processed 4600 / 5070 patients
# processed 4700 / 5070 patients
# processed 4800 / 5070 patients
# processed 4900 / 5070 patients
# processed 5000 / 5070 patients
#
#  2046
#
# 	(no events in ICU)  15614 episode1_timeseries.csv
# processed 100 / 36517 patients
# processed 200 / 36517 patients
#
# 	(no events in ICU)  24661 episode1_timeseries.csv
# processed 300 / 36517 patients
#
# 	(no events in ICU)  20014 episode1_timeseries.csv
# processed 400 / 36517 patients
# processed 500 / 36517 patients
# processed 600 / 36517 patients
# processed 700 / 36517 patients
# processed 800 / 36517 patients
#
# 	(no events in ICU)  18202 episode1_timeseries.csv
# processed 900 / 36517 patients
# processed 1000 / 36517 patients
# processed 1100 / 36517 patients
# processed 1200 / 36517 patients
# processed 1300 / 36517 patients
# processed 1400 / 36517 patients
#
# 	(no events in ICU)  23129 episode1_timeseries.csv
# processed 1500 / 36517 patients
#
# 	(no events in ICU)  20887 episode2_timeseries.csv
# processed 1600 / 36517 patients
# processed 1700 / 36517 patients
#
# 	(length of stay is missing) 20861 episode1_timeseries.csv
# processed 1800 / 36517 patients
# processed 1900 / 36517 patients
# processed 2000 / 36517 patients
# processed 2100 / 36517 patients
#
# 	(no events in ICU)  3755 episode1_timeseries.csv
# processed 2200 / 36517 patients
#
# 	(no events in ICU)  21170 episode1_timeseries.csv
# processed 2300 / 36517 patients
#
# 	(no events in ICU)  8613 episode1_timeseries.csv
# processed 2400 / 36517 patients
# processed 2500 / 36517 patients
#
# 	(no events in ICU)  5475 episode1_timeseries.csv
#
# 	(no events in ICU)  3582 episode1_timeseries.csv
# processed 2600 / 36517 patients
#
# 	(no events in ICU)  2970 episode1_timeseries.csv
# processed 2700 / 36517 patients
# processed 2800 / 36517 patients
#
# 	(no events in ICU)  16047 episode1_timeseries.csv
# processed 2900 / 36517 patients
#
# 	(no events in ICU)  30791 episode1_timeseries.csv
# processed 3000 / 36517 patients
#
# 	(no events in ICU)  11274 episode1_timeseries.csv
#
# 	(no events in ICU)  3376 episode1_timeseries.csv
#
# 	(no events in ICU)  1764 episode2_timeseries.csv
# processed 3100 / 36517 patients
# processed 3200 / 36517 patients
#
# 	(no events in ICU)  4889 episode1_timeseries.csv
# processed 3300 / 36517 patients
# processed 3400 / 36517 patients
#
# 	(no events in ICU)  7739 episode1_timeseries.csv
# processed 3500 / 36517 patients
# processed 3600 / 36517 patients
#
# 	(no events in ICU)  21680 episode1_timeseries.csv
# processed 3700 / 36517 patients
# processed 3800 / 36517 patients
# processed 3900 / 36517 patients
# processed 4000 / 36517 patients
# processed 4100 / 36517 patients
# processed 4200 / 36517 patients
#
# 	(no events in ICU)  32295 episode1_timeseries.csv
#
# 	(no events in ICU)  5374 episode2_timeseries.csv
# processed 4300 / 36517 patients
# processed 4400 / 36517 patients
# processed 4500 / 36517 patients
# processed 4600 / 36517 patients
#
# 	(no events in ICU)  11290 episode1_timeseries.csv
#
# 	(no events in ICU)  25333 episode1_timeseries.csv
# processed 4700 / 36517 patients
# processed 4800 / 36517 patients
#
# 	(no events in ICU)  10291 episode1_timeseries.csv
#
# 	(no events in ICU)  16118 episode2_timeseries.csv
# processed 4900 / 36517 patients
#
# 	(no events in ICU)  7639 episode1_timeseries.csv
# processed 5000 / 36517 patients
#
# 	(no events in ICU)  29295 episode1_timeseries.csv
# processed 5100 / 36517 patients
#
# 	(no events in ICU)  5704 episode1_timeseries.csv
# processed 5200 / 36517 patients
# processed 5300 / 36517 patients
#
# 	(no events in ICU)  31095 episode1_timeseries.csv
# processed 5400 / 36517 patients
#
# 	(length of stay is missing) 10168 episode1_timeseries.csv
# processed 5500 / 36517 patients
#
# 	(no events in ICU)  16467 episode1_timeseries.csv
# processed 5600 / 36517 patients
#
# 	(no events in ICU)  3296 episode1_timeseries.csv
# processed 5700 / 36517 patients
#
# 	(no events in ICU)  20765 episode1_timeseries.csv
# processed 5800 / 36517 patients
#
# 	(no events in ICU)  14580 episode1_timeseries.csv
#
# 	(no events in ICU)  5417 episode1_timeseries.csv
# processed 5900 / 36517 patients
# processed 6000 / 36517 patients
# processed 6100 / 36517 patients
#
# 	(no events in ICU)  637 episode1_timeseries.csv
# processed 6200 / 36517 patients
#
# 	(no events in ICU)  20937 episode1_timeseries.csv
#
# 	(no events in ICU)  20843 episode2_timeseries.csv
# processed 6300 / 36517 patients
# processed 6400 / 36517 patients
# processed 6500 / 36517 patients
# processed 6600 / 36517 patients
# processed 6700 / 36517 patients
# processed 6800 / 36517 patients
#
# 	(no events in ICU)  31412 episode1_timeseries.csv
# processed 6900 / 36517 patients
# processed 7000 / 36517 patients
# processed 7100 / 36517 patients
#
# 	(no events in ICU)  25125 episode1_timeseries.csv
# processed 7200 / 36517 patients
#
# 	(no events in ICU)  10575 episode1_timeseries.csv
# processed 7300 / 36517 patients
#
# 	(no events in ICU)  25135 episode1_timeseries.csv
# processed 7400 / 36517 patients
#
# 	(no events in ICU)  87160 episode1_timeseries.csv
# processed 7500 / 36517 patients
# processed 7600 / 36517 patients
#
# 	(length of stay is missing) 499 episode1_timeseries.csv
#
# 	(no events in ICU)  32596 episode1_timeseries.csv
#
# 	(no events in ICU)  85983 episode1_timeseries.csv
# processed 7700 / 36517 patients
# processed 7800 / 36517 patients
#
# 	(no events in ICU)  21287 episode1_timeseries.csv
# processed 7900 / 36517 patients
# processed 8000 / 36517 patients
# processed 8100 / 36517 patients
#
# 	(no events in ICU)  28316 episode1_timeseries.csv
# processed 8200 / 36517 patients
# processed 8300 / 36517 patients
# processed 8400 / 36517 patients
#
# 	(no events in ICU)  15029 episode1_timeseries.csv
#
# 	(no events in ICU)  8877 episode1_timeseries.csv
# processed 8500 / 36517 patients
# processed 8600 / 36517 patients
# processed 8700 / 36517 patients
#
# 	(no events in ICU)  25783 episode1_timeseries.csv
# processed 8800 / 36517 patients
# processed 8900 / 36517 patients
#
# 	(no events in ICU)  4026 episode2_timeseries.csv
# processed 9000 / 36517 patients
#
# 	(no events in ICU)  8552 episode1_timeseries.csv
# processed 9100 / 36517 patients
# processed 9200 / 36517 patients
#
# 	(no events in ICU)  4663 episode1_timeseries.csv
# processed 9300 / 36517 patients
#
# 	(no events in ICU)  28307 episode1_timeseries.csv
# processed 9400 / 36517 patients
#
# 	(no events in ICU)  4064 episode1_timeseries.csv
# processed 9500 / 36517 patients
#
# 	(no events in ICU)  29897 episode1_timeseries.csv
# processed 9600 / 36517 patients
# processed 9700 / 36517 patients
#
# 	(no events in ICU)  23501 episode1_timeseries.csv
# processed 9800 / 36517 patients
# processed 9900 / 36517 patients
# processed 10000 / 36517 patients
#
# 	(length of stay is missing) 10128 episode1_timeseries.csv
#
# 	(no events in ICU)  522 episode1_timeseries.csv
# processed 10100 / 36517 patients
#
# 	(no events in ICU)  7679 episode2_timeseries.csv
# 	(no events in ICU)  15215 episode1_timeseries.csv
# processed 10200 / 36517 patients
#
# 	(no events in ICU)  1966 episode1_timeseries.csv
# processed 10300 / 36517 patients
# processed 10400 / 36517 patients
#
# 	(no events in ICU)  29267 episode1_timeseries.csv
# processed 10500 / 36517 patients
#
# 	(no events in ICU)  32190 episode2_timeseries.csv
# processed 10600 / 36517 patients
#
# 	(no events in ICU)  5716 episode1_timeseries.csv
# processed 10700 / 36517 patients
#
# 	(no events in ICU)  98768 episode1_timeseries.csv
# processed 10800 / 36517 patients
#
# 	(no events in ICU)  13134 episode1_timeseries.csv
#
# 	(no events in ICU)  10166 episode1_timeseries.csv
# processed 10900 / 36517 patients
#
# 	(no events in ICU)  4156 episode1_timeseries.csv
# processed 11000 / 36517 patients
# processed 11100 / 36517 patients
# processed 11200 / 36517 patients
# processed 11300 / 36517 patients
#
# 	(no events in ICU)  15598 episode1_timeseries.csv
# processed 11400 / 36517 patients
# processed 11500 / 36517 patients
#
# 	(no events in ICU)  15348 episode2_timeseries.csv
# processed 11600 / 36517 patients
#
# 	(no events in ICU)  8468 episode1_timeseries.csv
# processed 11700 / 36517 patients
#
# 	(no events in ICU)  29585 episode1_timeseries.csv
# processed 11800 / 36517 patients
# processed 11900 / 36517 patients
# processed 12000 / 36517 patients
# processed 12100 / 36517 patients
#
# 	(no events in ICU)  7850 episode1_timeseries.csv
#
# 	(no events in ICU)  25601 episode1_timeseries.csv
# processed 12200 / 36517 patients
# processed 12300 / 36517 patients
#
# 	(no events in ICU)  19366 episode1_timeseries.csv
# processed 12400 / 36517 patients
# processed 12500 / 36517 patients
# processed 12600 / 36517 patients
# processed 12700 / 36517 patients
# processed 12800 / 36517 patients
#
# 	(length of stay is missing) 6462 episode1_timeseries.csv
# processed 12900 / 36517 patients
#
# 	(no events in ICU)  4179 episode1_timeseries.csv
# processed 13000 / 36517 patients
#
# 	(no events in ICU)  26168 episode2_timeseries.csv
# processed 13100 / 36517 patients
# processed 13200 / 36517 patients
# processed 13300 / 36517 patients
# processed 13400 / 36517 patients
# processed 13500 / 36517 patients
# processed 13600 / 36517 patients
#
# 	(no events in ICU)  5133 episode1_timeseries.csv
#
# 	(no events in ICU)  11221 episode1_timeseries.csv
# processed 13700 / 36517 patients
# processed 13800 / 36517 patients
# processed 13900 / 36517 patients
# processed 14000 / 36517 patients
# processed 14100 / 36517 patients
#
# 	(no events in ICU)  31184 episode2_timeseries.csv
# processed 14200 / 36517 patients
# processed 14300 / 36517 patients
# processed 14400 / 36517 patients
# processed 14500 / 36517 patients
# processed 14600 / 36517 patients
#
# 	(no events in ICU)  27907 episode1_timeseries.csv
# processed 14700 / 36517 patients
# processed 14800 / 36517 patients
# processed 14900 / 36517 patients
# processed 15000 / 36517 patients
#
# 	(no events in ICU)  892 episode1_timeseries.csv
#
# 	(no events in ICU)  19617 episode1_timeseries.csv
# processed 15100 / 36517 patients
#
# 	(no events in ICU)  7531 episode1_timeseries.csv
# processed 15200 / 36517 patients
#
# 	(no events in ICU)  1710 episode1_timeseries.csv
#
# 	(no events in ICU)  17454 episode1_timeseries.csv
# processed 15300 / 36517 patients
# processed 15400 / 36517 patients
# processed 15500 / 36517 patients
# processed 15600 / 36517 patients
# processed 15700 / 36517 patients
#
# 	(no events in ICU)  10334 episode1_timeseries.csv
# processed 15800 / 36517 patients
# processed 15900 / 36517 patients
# processed 16000 / 36517 patients
#
# 	(length of stay is missing) 19967 episode1_timeseries.csv
# processed 16100 / 36517 patients
# processed 16200 / 36517 patients
# processed 16300 / 36517 patients
#
# 	(no events in ICU)  988 episode1_timeseries.csv
# processed 16400 / 36517 patients
# processed 16500 / 36517 patients
#
# 	(no events in ICU)  16313 episode1_timeseries.csv
# processed 16600 / 36517 patients
# processed 16700 / 36517 patients
# processed 16800 / 36517 patients
# processed 16900 / 36517 patients
# processed 17000 / 36517 patients
#
# 	(no events in ICU)  7070 episode1_timeseries.csv
# processed 17100 / 36517 patients
# processed 17200 / 36517 patients
#
# 	(no events in ICU)  10450 episode1_timeseries.csv
# processed 17300 / 36517 patients
#
# 	(no events in ICU)  17951 episode1_timeseries.csv
# processed 17400 / 36517 patients
# processed 17500 / 36517 patients
#
# 	(no events in ICU)  14162 episode1_timeseries.csv
# processed 17600 / 36517 patients
# processed 17700 / 36517 patients
#
# 	(no events in ICU)  858 episode2_timeseries.csv
#
# 	(no events in ICU)  3012 episode1_timeseries.csv
#
# 	(no events in ICU)  76219 episode1_timeseries.csv
#
# 	(no events in ICU)  28969 episode1_timeseries.csv
# processed 17800 / 36517 patients
# processed 17900 / 36517 patients
#
# 	(no events in ICU)  79501 episode1_timeseries.csv
# processed 18000 / 36517 patients
# processed 18100 / 36517 patients
# processed 18200 / 36517 patients
#
# 	(no events in ICU)  16634 episode2_timeseries.csv
# processed 18300 / 36517 patients
# processed 18400 / 36517 patients
#
# 	(no events in ICU)  11799 episode1_timeseries.csv
# processed 18500 / 36517 patients
#
# 	(no events in ICU)  12516 episode1_timeseries.csv
# processed 18600 / 36517 patients
# processed 18700 / 36517 patients
# processed 18800 / 36517 patients
# processed 18900 / 36517 patients
# processed 19000 / 36517 patients
#
# 	(no events in ICU)  14200 episode2_timeseries.csv
#
# 	(no events in ICU)  2424 episode1_timeseries.csv
# processed 19100 / 36517 patients
# processed 19200 / 36517 patients
# processed 19300 / 36517 patients
# processed 19400 / 36517 patients
#
# 	(no events in ICU)  22978 episode1_timeseries.csv
# processed 19500 / 36517 patients
#
# 	(no events in ICU)  31396 episode1_timeseries.csv
# processed 19600 / 36517 patients
